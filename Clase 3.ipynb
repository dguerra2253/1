# %% [markdown]
# <a href="https://colab.research.google.com/github/dguerra2253/1/blob/main/Clase%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
x = { "Company" : ["Ford", "Ford", "VW", "BMW", "Cooper", "Cooper"],
     "Stars":[1, 2, np.nan, 3, 2, 2],
     "Weight": [2, 4, 2, 2, 3, None],
     "Origin": ["Mexico", "China","China","Mexico","UK",None],
     "Length": [40,50,30,np.nan,56,pd.NaT,40]
     }

# %%
type(x)
# Out:
# dict

# %%
df= pd.DataFrame(data= x)
df
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0  Mexico     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    NaN     2.0   China     30
# 3     BMW    3.0     2.0  Mexico    NaN
# 4  Cooper    2.0     3.0      UK     56
# 5  Cooper    2.0     NaN    None    NaT

# %%
df.isnull().any()
# Out:
# Company    False
# Stars       True
# Weight      True
# Origin      True
# Length      True
# dtype: bool

# %%
ndf=df.copy()
ndf.shape
# Out:
# (6, 5)

# %%
ndf.dropna()
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0  Mexico     40
# 1    Ford    2.0     4.0   China     50
# 4  Cooper    2.0     3.0      UK     56

# %%
ndf.isnull().any(axis=1)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
ndf.isnull().any(axis=0)
# Out:
# Company    False
# Stars       True
# Weight      True
# Origin      True
# Length      True
# dtype: bool

# %%
# Eliminar renglones con datos perdidos

# %%
ndf.dropna()
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0  Mexico     40
# 1    Ford    2.0     4.0   China     50
# 4  Cooper    2.0     3.0      UK     56

# %%
# Eliminar columnas con datos perdidos

# %%
ndf.dropna(axis=1)
# Out:
#   Company
# 0    Ford
# 1    Ford
# 2      VW
# 3     BMW
# 4  Cooper
# 5  Cooper

# %%
ndf.dropna(inplace=True)

# %%
ndf
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0  Mexico     40
# 1    Ford    2.0     4.0   China     50
# 4  Cooper    2.0     3.0      UK     56
